# %% [markdown]
# <center>Credit: MEJBAH AHAMMAD<center>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create the Random Samples Datasets for Complete the Simple Linear Regression Implementation
X = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# %%
# Calculate the Mean value for X and y
mean_for_x = np.mean(X)
mean_for_y = np.mean(y)

# %%
print("The mean value of X is: ", mean_for_x)
print("The mean value of Y is: ", mean_for_y)
# Out:
# The mean value of X is:  3.0
# The mean value of Y is:  4.0

# %%
rise = np.sum ((X - mean_for_x) * (y - mean_for_y))
run = np.sum ((X - mean_for_x)**2)

# %%
print("The value of Rise: ", rise)
print("The value of Run: ", run)
# Out:
# The value of Rise:  6.0
# The value of Run:  10.0

# %%
# Calculate the Slope for the simple linear regression
slope = rise / run

# %%
print("The slope value is: ", slope)
# Out:
# The slope value is:  0.6

# %%
# Calculate the intercept Value
intercept = mean_for_y - (slope * mean_for_x)
print("The Intercept value is: ", intercept)
# Out:
# The Intercept value is:  2.2

# %%
# Create the visualization
plt.scatter(X, y, color = "g", label = "Data observation")
plt.plot(X, slope * X + intercept, color = "r", label = "Simple linear regression line")
plt.legend()
plt.xlabel("Independent data points")
plt.ylabel("Dependent data points")
plt.title("Simple Linear Regression")
plt.show()
